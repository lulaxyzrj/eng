# %%
import pyspark.sql.functions as F

  

df = spark.read.format("json").load(

"abfss://landing@adlsubereatsdevsji8.dfs.core.windows.net/mongodb/items/*.jsonl"

).select(

"*",

F.col("_metadata.file_path").alias("source_file"),

F.col("_metadata.file_modification_time").alias("ingestion_time")

)
display(df)
# Out:
# DataFrame[cuisine_type: string, discount_applied: double, dt_current_timestamp: string, is_combo: boolean, is_vegetarian: boolean, modifiers: string, order_id: string, order_item_id: string, product_id: string, product_name: string, product_type: string, quantity: bigint, restaurant_id: bigint, subtotal: double, unit_price: double, source_file: string, ingestion_time: timestamp]

# %%
df.write.format("delta").mode("overwrite").saveAsTable("ubereats_dev.bronze.mongo_items")
